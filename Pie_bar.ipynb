# %%
import plotly.graph_objs as go
import pandas as pd
import plotly.offline as off
off.init_notebook_mode(connected=True)
import folium
import os
#os.chdir("D:\GSU\Study\Summer\Data_Vis\Finalpro")

df = pd.read_csv('fastfoodmaps_locations_2007.csv')
df.loc['Name']= df['Type']
df.loc[df['Type']== 'b','Name']='Burger King'
df.loc[df['Type']== 'm','Name']='McDonalds'
df.loc[df['Type']== 'p','Name']='Pizza Hut'
df.loc[df['Type']== 't','Name']='Taco Bell'
df.loc[df['Type']== 'w','Name']="Wendy's"
df.loc[df['Type']== 'k','Name']='KFC'
df.loc[df['Type']== 'j','Name']='Jack'
df.loc[df['Type']== 'c','Name']="Carl's Jr."
df.loc[df['Type']== 'i','Name']='In-N-Out'
df.loc[df['Type']== 'h','Name']="Hardee's"
df['text'] = df['Name']+ '<br>'+ df['Location'] + ', ' + df['State'] + ', ' + df['Zip']
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df_all=df[["Name","Location"]]
allpie=df_all.groupby(["Name"],as_index=False).count()
fig = go.Figure(data=[go.Pie(labels=allpie.Name, values=allpie.Location, hole=.3)])
fig.show()
# Out:
# <div>
#
#
#             <div id="23c4ccaa-3591-4be6-a1c2-39ae7bd15bc3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("23c4ccaa-3591-4be6-a1c2-39ae7bd15bc3")) {
#                     Plotly.newPlot(
#                         '23c4ccaa-3591-4be6-a1c2-39ae7bd15bc3',
#                         [{"hole": 0.3, "labels": ["Burger King", "Carl's Jr.", "Hardee's", "In-N-Out", "Jack", "KFC", "McDonalds", "Pizza Hut", "Taco Bell", "Wendy's"], "type": "pie", "uid": "f6f235db-b8c0-4fe7-b3ba-a873ef657478", "values": [7435, 987, 1802, 203, 2057, 5424, 13745, 6214, 6164, 5971]}],
#                         {},
#                         {"plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('23c4ccaa-3591-4be6-a1c2-39ae7bd15bc3');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
lmt=["McDonalds","Burger King","Wendy's","KFC"]
dfa=df[df["Name"].isin(lmt)]
m=dfa.groupby(["Name"],as_index=False).count()


trace= [go.Bar(
    x=m.Name,
    y=m.Location
    )]
layout = go.Layout(
    title="The Number Of Store For Each Brand",
    autosize=False,
                width=800,
                height=500,
    xaxis=dict(title="Fastfood Brand",
              tickfont=dict(
                size=8
        )),
    yaxis=dict(title="Number Of Store"),
    annotations=[
        go.layout.Annotation(
            x=m['Name'][0],
            y=m['Number'][0],
            xref="x",
            yref="y",
            text=m['Name'][0] + ':' + m['Number'][0].astype(str),
            showarrow=True,
            align="center",
            arrowhead=2,
            arrowsize=1,
            arrowwidth=2,
            arrowcolor="#636363",
            ax=20,
            ay=-30,
            bordercolor="#c7c7c7",
            borderwidth=2,
            borderpad=4,
            bgcolor="#ff7f0e",
            opacity=0.8
        ),
        go.layout.Annotation(
            x=m['Name'][1],
            y=m['Number'][1],
            xref="x",
            yref="y",
            text=m['Name'][1] + ':' + m['Number'][1].astype(str),
            showarrow=True,
            align="center",
            arrowhead=2,
            arrowsize=1,
            arrowwidth=2,
            arrowcolor="#636363",
            ax=20,
            ay=-30,
            bordercolor="#c7c7c7",
            borderwidth=2,
            borderpad=4,
            bgcolor="#ff7f0e",
            opacity=0.8
        ),
        go.layout.Annotation(
            x=m['Name'][1],
            y=m['Number'][1],
            xref="x",
            yref="y",
            text=m['Name'][1] + ':' + m['Number'][1].astype(str),
            showarrow=True,
            align="center",
            arrowhead=2,
            arrowsize=1,
            arrowwidth=2,
            arrowcolor="#636363",
            ax=20,
            ay=-30,
            bordercolor="#c7c7c7",
            borderwidth=2,
            borderpad=4,
            bgcolor="#ff7f0e",
            opacity=0.8
        ),
        go.layout.Annotation(
            x=m['Name'][2],
            y=m['Number'][2],
            xref="x",
            yref="y",
            text=m['Name'][2] + ':' + m['Number'][2].astype(str),
            showarrow=True,
            align="center",
            arrowhead=2,
            arrowsize=1,
            arrowwidth=2,
            arrowcolor="#636363",
            ax=20,
            ay=-30,
            bordercolor="#c7c7c7",
            borderwidth=2,
            borderpad=4,
            bgcolor="#ff7f0e",
            opacity=0.8
        ),
                go.layout.Annotation(
            x=m['Name'][3],
            y=m['Number'][3],
            xref="x",
            yref="y",
            text=m['Name'][3] + ':' + m['Number'][3].astype(str),
            showarrow=True,
            align="center",
            arrowhead=2,
            arrowsize=1,
            arrowwidth=2,
            arrowcolor="#636363",
            ax=20,
            ay=-30,
            bordercolor="#c7c7c7",
            borderwidth=2,
            borderpad=4,
            bgcolor="#ff7f0e",
            opacity=0.8
        )
    ]
)

fig = go.Figure(data=trace,layout=layout)
off.iplot(fig)
# Out:
# <div>
#
#
#             <div id="3f6a7741-3364-4850-9493-91d460f6826e" class="plotly-graph-div" style="height:500px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("3f6a7741-3364-4850-9493-91d460f6826e")) {
#                     Plotly.newPlot(
#                         '3f6a7741-3364-4850-9493-91d460f6826e',
#                         [{"type": "bar", "uid": "920297d0-8819-4a12-b1e6-99039833ee7a", "x": ["Burger King", "KFC", "McDonalds", "Wendy's"], "y": [7435, 5424, 13745, 5971]}],
#                         {"annotations": [{"align": "center", "arrowcolor": "#636363", "arrowhead": 2, "arrowsize": 1, "arrowwidth": 2, "ax": 20, "ay": -30, "bgcolor": "#ff7f0e", "bordercolor": "#c7c7c7", "borderpad": 4, "borderwidth": 2, "opacity": 0.8, "showarrow": true, "text": "Burger King:7435", "x": "Burger King", "xref": "x", "y": 7435, "yref": "y"}, {"align": "center", "arrowcolor": "#636363", "arrowhead": 2, "arrowsize": 1, "arrowwidth": 2, "ax": 20, "ay": -30, "bgcolor": "#ff7f0e", "bordercolor": "#c7c7c7", "borderpad": 4, "borderwidth": 2, "opacity": 0.8, "showarrow": true, "text": "KFC:5424", "x": "KFC", "xref": "x", "y": 5424, "yref": "y"}, {"align": "center", "arrowcolor": "#636363", "arrowhead": 2, "arrowsize": 1, "arrowwidth": 2, "ax": 20, "ay": -30, "bgcolor": "#ff7f0e", "bordercolor": "#c7c7c7", "borderpad": 4, "borderwidth": 2, "opacity": 0.8, "showarrow": true, "text": "KFC:5424", "x": "KFC", "xref": "x", "y": 5424, "yref": "y"}, {"align": "center", "arrowcolor": "#636363", "arrowhead": 2, "arrowsize": 1, "arrowwidth": 2, "ax": 20, "ay": -30, "bgcolor": "#ff7f0e", "bordercolor": "#c7c7c7", "borderpad": 4, "borderwidth": 2, "opacity": 0.8, "showarrow": true, "text": "McDonalds:13745", "x": "McDonalds", "xref": "x", "y": 13745, "yref": "y"}, {"align": "center", "arrowcolor": "#636363", "arrowhead": 2, "arrowsize": 1, "arrowwidth": 2, "ax": 20, "ay": -30, "bgcolor": "#ff7f0e", "bordercolor": "#c7c7c7", "borderpad": 4, "borderwidth": 2, "opacity": 0.8, "showarrow": true, "text": "Wendy's:5971", "x": "Wendy's", "xref": "x", "y": 5971, "yref": "y"}], "autosize": false, "height": 500, "title": {"text": "The Number Of Store For Each Brand"}, "width": 800, "xaxis": {"tickfont": {"size": 8}, "title": {"text": "Fastfood Brand"}}, "yaxis": {"title": {"text": "Number Of Store"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('3f6a7741-3364-4850-9493-91d460f6826e');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
df_state=df[["Name","State",'Number']]
stateNumber = df_state.groupby(['Name', 'State']).size().reset_index(name='count')
x = stateNumber['State']

lmt=["McDonalds","Burger King","Wendy's","KFC"]

fig = go.Figure()
for k in lmt:
    y = stateNumber['count'][stateNumber['Name']==k]
    fig.add_trace(go.Bar(x=x, y=y,name = k))

fig.layout.update(barmode='relative', title_text='Numbers of the Stores in Each State',
    xaxis=dict(title="State"),
    yaxis=dict(title="Fastfood Brand"))
fig.show()
# Out:
# <div>
#
#
#             <div id="e538d26f-862c-4107-847c-db21d694f819" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e538d26f-862c-4107-847c-db21d694f819")) {
#                     Plotly.newPlot(
#                         'e538d26f-862c-4107-847c-db21d694f819',
#                         [{"name": "McDonalds", "type": "bar", "uid": "88dc538e-8c49-4e50-a8e5-67c4c28be32f", "x": ["AK", "AL", "AR", "AZ", "CA", "CO", "CT", "DC", "DE", "FL", "GA", "HI", "IA", "ID", "IL", "IN", "KS", "KY", "LA", "MA", "MD", "ME", "MI", "MN", "MO", "MS", "MT", "NC", "ND", "NE", "NH", "NJ", "NM", "NV", "NY", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VA", "VT", "WA", "WI", "WV", "WY", "AK", "AZ", "CA", "CO", "HI", "ID", "NM", "NV", "OK", "OR", "TX", "UT", "WA", "AL", "AR", "DE", "FL", "GA", "IA", "IL", "IN", "KS", "KY", "LA", "MD", "MI", "MN", "MO", "MS", "MT", "NC", "ND", "NE", "OH", "OK", "PA", "SC", "SD", "TN", "VA", "WI", "WV", "WY", "AZ", "CA", "NV", "AZ", "CA", "HI", "ID", "IL", "LA", "MO", "NC", "NM", "NV", "OK", "OR", "SC", "TN", "TX", "UT", "WA", "AK", "AL", "AR", "AZ", "CA", "CO", "CT", "DC", "DE", "FL", "GA", "IA", "ID", "IL", "IN", "KS", "KY", "LA", "MA", "MD", "ME", "MI", "MN", "MO", "MS", "NC", "ND", "NE", "NH", "NJ", "NM", "NV", "NY", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VA", "VT", "WA", "WI", "WV", "WY", "AK", "AL", "AR", "AZ", "CA", "CO", "CT", "DC", "DE", "FL", "GA", "HI", "IA", "ID", "IL", "IN", "KS", "KY", "LA", "MA", "MD", "ME", "MI", "MN", "MO", "MS", "MT", "NC", "ND", "NE", "NH", "NJ", "NM", "NV", "NY", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VA", "VT", "WA", "WI", "WV", "WY", "AK", "AL", "AR", "AZ", "CA", "CO", "CT", "DC", "DE", "FL", "GA", "HI", "IA", "ID", "IL", "IN", "KS", "KY", "LA", "MA", "MD", "ME", "MI", "MN", "MO", "MS", "MT", "NC", "ND", "NE", "NH", "NJ", "NM", "NV", "NY", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VA", "VT", "WA", "WI", "WV", "WY", "AK", "AL", "AR", "AZ", "CA", "CO", "CT", "DC", "DE", "FL", "GA", "IA", "ID", "IL", "IN", "KS", "KY", "LA", "MA", "MD", "ME", "MI", "MN", "MO", "MS", "MT", "NC", "ND", "NE", "NH", "NJ", "NM", "NV", "NY", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VA", "VT", "WA", "WI", "WV", "WY", "AK", "AL", "AR", "AZ", "CA", "CO", "CT", "DC", "DE", "FL", "GA", "HI", "IA", "ID", "IL", "IN", "KS", "KY", "LA", "MA", "MD", "ME", "MI", "MN", "MO", "MS", "MT", "NC", "ND", "NE", "NH", "NJ", "NM", "NV", "NY", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VA", "VT", "WA", "WI", "WV", "WY"], "y": [30, 236, 156, 251, 1322, 208, 154, 34, 34, 812, 416, 74, 141, 57, 663, 352, 156, 235, 249, 297, 302, 60, 553, 218, 316, 138, 46, 404, 23, 79, 63, 278, 92, 142, 705, 642, 195, 171, 549, 34, 202, 32, 325, 1066, 102, 415, 29, 275, 292, 94, 26]}, {"name": "Burger King", "type": "bar", "uid": "d862186c-4c84-4771-9b97-352248fa4859", "x": ["AK", "AL", "AR", "AZ", "CA", "CO", "CT", "DC", "DE", "FL", "GA", "HI", "IA", "ID", "IL", "IN", "KS", "KY", "LA", "MA", "MD", "ME", "MI", "MN", "MO", "MS", "MT", "NC", "ND", "NE", "NH", "NJ", "NM", "NV", "NY", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VA", "VT", "WA", "WI", "WV", "WY", "AK", "AZ", "CA", "CO", "HI", "ID", "NM", "NV", "OK", "OR", "TX", "UT", "WA", "AL", "AR", "DE", "FL", "GA", "IA", "IL", "IN", "KS", "KY", "LA", "MD", "MI", "MN", "MO", "MS", "MT", "NC", "ND", "NE", "OH", "OK", "PA", "SC", "SD", "TN", "VA", "WI", "WV", "WY", "AZ", "CA", "NV", "AZ", "CA", "HI", "ID", "IL", "LA", "MO", "NC", "NM", "NV", "OK", "OR", "SC", "TN", "TX", "UT", "WA", "AK", "AL", "AR", "AZ", "CA", "CO", "CT", "DC", "DE", "FL", "GA", "IA", "ID", "IL", "IN", "KS", "KY", "LA", "MA", "MD", "ME", "MI", "MN", "MO", "MS", "NC", "ND", "NE", "NH", "NJ", "NM", "NV", "NY", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VA", "VT", "WA", "WI", "WV", "WY", "AK", "AL", "AR", "AZ", "CA", "CO", "CT", "DC", "DE", "FL", "GA", "HI", "IA", "ID", "IL", "IN", "KS", "KY", "LA", "MA", "MD", "ME", "MI", "MN", "MO", "MS", "MT", "NC", "ND", "NE", "NH", "NJ", "NM", "NV", "NY", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VA", "VT", "WA", "WI", "WV", "WY", "AK", "AL", "AR", "AZ", "CA", "CO", "CT", "DC", "DE", "FL", "GA ...
